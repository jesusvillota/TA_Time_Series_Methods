// %% [markdown]
// <div style="max-width: 700px; margin: 20px auto 30px; padding: 20px; text-align: center; border-bottom: 2px solid #e5e7eb;">
//   <a href="2_1_simul_multivariate.ipynb" style="display: inline-block; padding: 10px 24px; background: #f9fafb; color: #38549c; text-decoration: none; border-radius: 8px; font-weight: 600; font-size: 14px; border: 1px solid #e5e7eb; margin-right: 12px;">
//     ← Part 2 - Multivariate Time Series Simulations
//   </a>
// </div>

// %% [markdown]
// <div style="max-width: 880px; margin: 20px auto 22px; padding: 0px; border-radius: 18px; border: 1px solid #e5e7eb; background: linear-gradient(180deg, #ffffff 0%, #f9fafb 100%); box-shadow: 0 8px 26px rgba(0,0,0,0.06); overflow: hidden;">
//
//   <!-- Banner Header -->
//   <div style="padding: 34px 32px 14px; text-align: center; line-height: 1.38;">
//     <div style="font-size: 13px; letter-spacing: 0.14em; text-transform: uppercase; color: #6b7280; font-weight: bold; margin-bottom: 5px;">
//       Session #2 • Part 3
//     </div>
//     <div style="font-size: 29px; font-weight: 800; color: #14276c; margin-bottom: 4px;">
//       Cointegration analysis: GDP-GDI
//     </div>
//     <div style="font-size: 16.5px; color: #374151; font-style: italic; margin-bottom: 0;">
//       Advanced Training School: Methods for Time Series
//     </div>
//   </div>
//
//   <!-- Logo Section -->
//   <div style="background: none; text-align: center; margin: 30px 0 10px;">
//     <img src="https://www.cemfi.es/images/Logo-Azul.png" alt="CEMFI Logo" style="width: 158px; filter: drop-shadow(0 2px 12px rgba(56,84,156,0.05)); margin-bottom: 0;">
//   </div>
//
//   <!-- Name -->
//   <div style="font-family: 'Times New Roman', Times, serif; color: #38549c; text-align: center; font-size: 1.22em; font-weight: bold; margin-bottom: 0px;">
//     Jesus Villota Miranda © 2025
//   </div>
//
//   <!-- Contact info -->
//   <div style="font-family: 'Times New Roman', Times, serif; color: #38549c; text-align: center; font-size: 1em; margin-top: 7px; margin-bottom: 20px;">
//     <a href="mailto:jesus.villota@cemfi.edu.es" style="color: #38549c; text-decoration: none; margin-right:8px;" title="Email">
//       jesus.villota@cemfi.edu.es
//     </a>
//     <span style="color:#9fa7bd;">|</span>
//     <a href="https://www.linkedin.com/in/jesusvillotamiranda/" target="_blank" style="color: #38549c; text-decoration: none; margin-left:7px;" title="LinkedIn">
//       LinkedIn
//     </a>
//   </div>
// </div>

// %% [markdown]
// <div style="max-width: 700px; margin: 20px auto 30px; padding: 24px 32px; border-radius: 18px; border: 1px solid #e5e7eb; background: linear-gradient(180deg, #ffffff 0%, #f9fafb 100%); box-shadow: 0 8px 26px rgba(0,0,0,0.06);">
//
// <div style="font-size: 22px; font-weight: 700; color: #14276c; margin-bottom: 16px; text-align: center;">
//   Table of Contents
// </div>
//
// <div style="font-size: 15px; color: #374151; line-height: 1.8;">
//   <div style="margin-bottom: 12px;"><strong>1.</strong> <a href="#section-1" style="color: #38549c; text-decoration: none;">Introduction to Cointegration</a></div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">1.1 What is Cointegration?</div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">1.2 The GDP-GDI Relationship</div>
//   <div style="margin-left: 20px; margin-bottom: 12px; font-size: 14px;">1.3 Why Cointegration Matters</div>
//
//   <div style="margin-bottom: 12px;"><strong>2.</strong> <a href="#section-2" style="color: #38549c; text-decoration: none;">Data Loading and Initial Exploration</a></div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">2.1 Loading the Data</div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">2.2 Time Series Visualization</div>
//   <div style="margin-left: 20px; margin-bottom: 12px; font-size: 14px;">2.3 Scatter Plot and Linear Relationship</div>
//
//   <div style="margin-bottom: 12px;"><strong>3.</strong> <a href="#section-3" style="color: #38549c; text-decoration: none;">Unit Root Testing</a></div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">3.1 Testing GDP for Unit Root</div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">3.2 Testing GDI for Unit Root</div>
//   <div style="margin-left: 20px; margin-bottom: 12px; font-size: 14px;">3.3 ACF/PACF Analysis</div>
//
//   <div style="margin-bottom: 12px;"><strong>4.</strong> <a href="#section-4" style="color: #38549c; text-decoration: none;">Testing for Cointegration</a></div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">4.1 Johansen Cointegration Test</div>
//   <div style="margin-left: 20px; margin-bottom: 12px; font-size: 14px;">4.2 Interpreting Test Results</div>
//
//   <div style="margin-bottom: 12px;"><strong>5.</strong> <a href="#section-5" style="color: #38549c; text-decoration: none;">The Cointegrating Relationship</a></div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">5.1 Estimating the Cointegrating Vector</div>
//   <div style="margin-left: 20px; margin-bottom: 12px; font-size: 14px;">5.2 The Error Correction Term</div>
//
//   <div style="margin-bottom: 12px;"><strong>6.</strong> <a href="#section-6" style="color: #38549c; text-decoration: none;">Vector Error Correction Model (VECM)</a></div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">6.1 VECM Estimation</div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">6.2 Impulse Response Functions</div>
//   <div style="margin-left: 20px; margin-bottom: 12px; font-size: 14px;">6.3 Variance Decomposition</div>
//
//   <div style="margin-bottom: 12px;"><strong>7.</strong> <a href="#section-7" style="color: #38549c; text-decoration: none;">Model Diagnostics</a></div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">7.1 Residual Analysis</div>
//   <div style="margin-left: 20px; margin-bottom: 8px; font-size: 14px;">7.2 Stability Tests</div>
//   <div style="margin-left: 20px; margin-bottom: 12px; font-size: 14px;">7.3 Granger Causality</div>
//
//   <div style="margin-bottom: 0px;"><strong>8.</strong> <a href="#section-8" style="color: #38549c; text-decoration: none;">Economic Interpretation and Conclusions</a></div>
// </div>
//
// </div>

// %% [markdown]
// <link rel="stylesheet" href="../notebook_styles.css">

// %% [markdown]
// <a id="section-1"></a>
// <h2 class="styled-header">1) Introduction to Cointegration</h2>
//
// ### 1.1 What is Cointegration?
//
// **Cointegration** is a fundamental concept in time series econometrics that describes the long-run equilibrium relationship between two or more non-stationary variables. When variables are cointegrated, they share a common stochastic trend and cannot drift arbitrarily far apart over time.
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Formal Definition**
//
// Two time series $X_t$ and $Y_t$ are **cointegrated** of order $(d, b)$, denoted $X_t, Y_t \sim CI(d,b)$, if:
//
// 1. Both series are integrated of order $d$: $X_t \sim I(d)$ and $Y_t \sim I(d)$
// 2. There exists a linear combination that is integrated of order $d-b$ where $b > 0$:
//    $$Z_t = Y_t - \beta X_t \sim I(d-b)$$
//
// The most common case is $CI(1,1)$ where both series are $I(1)$ but their linear combination is $I(0)$ (stationary).
//
// </div>
//
// **Mathematical Representation:**
//
// If $X_t$ and $Y_t$ are both $I(1)$ processes (unit root processes), they can be written as:
//
// $$
// \begin{aligned}
// X_t &= X_{t-1} + \varepsilon_{1t} \\
// Y_t &= Y_{t-1} + \varepsilon_{2t}
// \end{aligned}
// $$
//
// If cointegrated with cointegrating vector $(1, -\beta)$, then:
//
// $$
// Z_t = Y_t - \beta X_t \sim I(0)
// $$
//
// The parameter $\beta$ is called the **cointegrating coefficient**, and $Z_t$ is the **error correction term** or **cointegrating residual**.
//
// ### 1.2 The GDP-GDI Relationship
//
// **GDP (Gross Domestic Product)** and **GDI (Gross Domestic Income)** represent two sides of the same national accounting identity. In theory, they should be equal:
//
// $$
// \text{GDP} = \text{GDI}
// $$
//
// **Why?**
// - **GDP**: Measures total value of goods and services produced (production approach)
// - **GDI**: Measures total income generated by production (income approach)
// - By definition, every dollar of production generates a dollar of income
//
// **In Practice:**
// - Measurement errors create statistical discrepancy: $\text{GDP} \neq \text{GDI}$
// - Both series trend upward over time (non-stationary, $I(1)$)
// - If cointegrated with $\beta \approx 1$, this confirms the theoretical identity
// - Deviations from equilibrium ($Z_t = \text{GDI}_t - \beta \cdot \text{GDP}_t$) should be temporary

// %% [markdown]
// <div style="background: linear-gradient(135deg, #fef3c7 0%, #fde68a 100%); border-left: 4px solid #f59e0b; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **⚠️ The Spurious Regression Problem**
//
// If we regress one $I(1)$ series on another $I(1)$ series using OLS:
//
// $$Y_t = \alpha + \beta X_t + u_t$$
//
// Without cointegration:
// - Standard errors are invalid → t-statistics are misleading
// - $R^2$ tends to be artificially high
// - Residuals $u_t$ are non-stationary → violates OLS assumptions
// - We find "significant" relationships that are purely spurious
//
// **Solution:** Test for cointegration first! If cointegrated, use VECM instead of standard regression.
//
// </div>
//
// <div style="background: linear-gradient(135deg, #fff5f5 0%, #ffe5e5 100%); border-left: 4px solid #dc2626; padding: 20px; border-radius: 8px; margin: 20px 0;">
//
// **The Spurious Regression Problem**: One of the most important discoveries in econometrics (Granger & Newbold, 1974) is that regressing one non-stationary series on another can produce **highly misleading results** even when the variables are completely independent.
//
// </div>
//
// To visualize this, we construct two **independent random walks** with no causal relationship whatsoever:
//
// $$
// \begin{align*}
// x_t &= x_{t-1} + \varepsilon_t, \quad x_0 = 0 \\
// y_t &= y_{t-1} + \nu_t, \quad y_0 = 0
// \end{align*}
// $$
//
// where $\varepsilon_t, \nu_t \stackrel{\text{i.i.d.}}{\sim} \mathcal{N}(0,1)$ are **independent** standard normal shocks.
//
// **Key Properties of Random Walks**:
// 1. **Non-stationary**: $\mathbb{E}[x_t] = 0$ but $\text{Var}(x_t) = t\sigma^2 \to \infty$ as $t \to \infty$
// 2. **No mean reversion**: Shocks have permanent effects
// 3. **Trending behavior**: Series wander away from their starting values
//
// #### The Spurious Regression
//
// Despite being generated independently, when we estimate:
//
// $$y_t = \alpha + \beta x_t + u_t$$
//
// we typically observe:
// - **Inflated $R^2$**
// - **Significant t-statistics** (often |t| > 2) suggesting "significant" relationship
// - **Low Durbin-Watson statistic** (DW ≈ 0) indicating strongly serially correlated residuals
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 16px; border-radius: 6px; margin: 16px 0;">
//
// **Why This Happens**: Both series drift randomly over time. By chance, they may drift in similar directions during certain periods, creating the **illusion** of a relationship. The residuals $\hat{u}_t$ inherit the non-stationarity of $x_t$ and $y_t$, violating the basic assumption that errors are stationary with constant variance.
//
// </div>

// %%
* ---------------------------------------------------------------------------
* Spurious Regression Demonstration: Two Independent Random Walks
* ---------------------------------------------------------------------------

clear all
set obs 250                    // Sample size (250 observations)
set seed 12345                 // Seed that produces more typical spurious result

* Generate time index and declare as time series
gen t = _n
tsset t                        // Declare time series structure

* Generate independent random shocks: ε_t, ν_t ~ N(0,1)
gen eps = rnormal()
gen nu = rnormal()

* Construct random walks: x_t = x_{t-1} + ε_t, y_t = y_{t-1} + ν_t
gen x_rw = sum(eps)            // Cumulative sum creates random walk
gen y_rw = sum(nu)             // Completely independent of x_rw

* Display summary statistics for the random walks
display _newline "{txt}{hline 60}"
display "{txt}Summary Statistics for Independent Random Walks"
display "{txt}{hline 60}"
summarize x_rw y_rw

* Correlation between contemporaneous values (spurious!)
display _newline "{txt}Correlation between independent random walks:"
correlate x_rw y_rw

* Run the spurious regression: y_t = α + β·x_t + u_t
display _newline "{txt}{hline 60}"
display "{txt}Spurious Regression: y_t = α + β·x_t + u_t"
display "{txt}{hline 60}"
quietly regress y_rw x_rw

* Calculate Durbin-Watson statistic explicitly
quietly estat dwatson
local dw = r(dw)

* Extract key statistics
local beta = _b[x_rw]
local se_beta = _se[x_rw]
local t_stat = `beta'/`se_beta'
local r2 = e(r2)
local N = e(N)

* Display full regression output
regress y_rw x_rw

* Display interpretation
display _newline "{txt}{hline 60}"
display "{txt}Spurious Regression Results Summary:"
display "{txt}{hline 60}"
display "{txt}Coefficient (β):     {res}" %7.4f `beta' "{txt}  (should be ~0 if no relation)"
display "{txt}Standard Error:      {res}" %7.4f `se_beta'
display "{txt}t-statistic:         {res}" %7.3f `t_stat' "{txt}  (appears 'significant'!)"
display "{txt}R-squared:           {res}" %7.4f `r2' "{txt}  (" %4.1f `r2'*100 "% of variation 'explained')"
display "{txt}Durbin-Watson:       {res}" %7.4f `dw' "{txt}  (DW≈0 indicates strong serial correlation)"
display "{txt}{hline 60}"
display "{err}⚠  WARNING: Despite statistical significance,"
display "{err}   these series are INDEPENDENT by construction!"
display "{err}   This demonstrates the SPURIOUS REGRESSION problem."
display "{txt}{hline 60}" _newline

* Generate predictions and residuals for visualization
predict yhat, xb
predict resid, resid

* VISUALIZATION 1: Time series plots of both random walks
twoway (line x_rw t, lcolor(navy) lwidth(medium)) ///
       (line y_rw t, lcolor(maroon) lwidth(medium)), ///
    title("Two Independent Random Walks", size(medium) color(black)) ///
    subtitle("Both series drift randomly with no causal link", size(small)) ///
    ytitle("Value", size(small)) xtitle("Time", size(small)) ///
    legend(order(1 "x{subscript:t} (random walk 1)" 2 "y{subscript:t} (random walk 2)") ///
           size(small) position(6) rows(1)) ///
    name(sr_timeseries, replace)

* VISUALIZATION 2: Scatter plot with spurious regression line
twoway (scatter y_rw x_rw, msymbol(circle) msize(small) mcolor(navy%40)) ///
       (lfit y_rw x_rw, lcolor(red) lwidth(medthick)), ///
    title("Spurious Regression: y{subscript:t} vs x{subscript:t}", size(medium) color(black)) ///
    subtitle("R² = `: display %4.3f `r2'' with t = `: display %4.2f `t_stat'' despite independence", size(small)) ///
    ytitle("y{subscript:t} (random walk 2)", size(small)) ///
    xtitle("x{subscript:t} (random walk 1)", size(small)) ///
    legend(order(1 "Observed pairs" 2 "OLS fit: β = `: display %5.3f `beta''") ///
           size(small) position(6) rows(1)) ///
    note("False relationship due to both series being non-stationary", size(vsmall)) ///
    name(sr_scatter, replace)

* VISUALIZATION 3: Residual plot showing non-stationary behavior
twoway (line resid t, lcolor(red) lwidth(medium)) ///
       (line yhat t, lcolor(blue%30) lwidth(thin) lpattern(dash)), ///
    title("Non-Stationary Residuals from Spurious Regression", size(medium) color(black)) ///
    subtitle("Residuals drift and exhibit strong persistence (DW = `: display %4.3f `dw'')", size(small)) ///
    ytitle("Value", size(small)) xtitle("Time", size(small)) ///
    yline(0, lcolor(gs10) lpattern(solid)) ///
    legend(order(1 "Residuals (û{subscript:t})" 2 "Fitted values (ŷ{subscript:t})") ///
           size(small) position(6) rows(1)) ///
    name(sr_resid, replace)

* VISUALIZATION 4: ACF of residuals (should show strong persistence)
ac resid, lags(40) ///
    title("ACF of Residuals: Evidence of Non-Stationarity", size(medium)) ///
    subtitle("Slow decay indicates residuals inherit the unit root", size(small)) ///
    name(sr_acf_resid, replace)
// Out:
// Number of observations (_N) was 0, now 250.
//
//
//
//
// Time variable: t, 1 to 250
//         Delta: 1 unit
//
//
//
//
//
//
// ------------------------------------------------------------
//
// Summary Statistics for Independent Random Walks
//
// ------------------------------------------------------------
//
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//         x_rw |        250    13.16363    5.139517    .957395   25.76464
//         y_rw |        250    4.826374    4.171077   -5.33087   14.42246
//
//
// Correlation between independent random walks:
//
// (obs=250)
//
//              |     x_rw     y_rw
// -------------+------------------
//         x_rw |   1.0000
//         y_rw |  -0.2337   1.0000
//
//
//
// ------------------------------------------------------------
//
// Spurious Regression: y_t = α + β·x_t + u_t
//
// ...

// %% [markdown]
// ### 1.3 Why Cointegration Matters
//
// Cointegration has profound implications for economic modeling and policy:
//
// 1. **Long-run Equilibrium**: Identifies stable relationships between variables
// 2. **Error Correction**: Shows how variables adjust to restore equilibrium
// 3. **Forecasting**: Improves long-horizon predictions by incorporating equilibrium constraint
// 4. **Policy Analysis**: Reveals which variables adjust when disequilibrium occurs
// 5. **Economic Theory**: Tests theoretical relationships (like GDP = GDI)
//
// **Key Distinction:**
//
// | Concept | Description | Example |
// |---------|-------------|---------|
// | **Correlation** | Short-run co-movement | Two stocks move together daily |
// | **Cointegration** | Long-run equilibrium | GDP and GDI cannot diverge permanently |
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🎯 Learning Objectives**
//
// In this notebook, we will:
// 1. Test whether Spanish GDP and GDI are both $I(1)$ processes
// 2. Apply Johansen cointegration test to detect long-run relationship
// 3. Estimate the cointegrating vector and interpret economic meaning
// 4. Build a Vector Error Correction Model (VECM)
// 5. Analyze how each variable adjusts to restore equilibrium
// 6. Validate results through diagnostic tests
//
// </div>

// %% [markdown]
// <a id="section-2"></a>
// <h2 class="styled-header">2) Data Loading and Initial Exploration</h2>
//
// ### 2.1 Loading the Data
//
// We'll work with two US macroeconomic series:
// - **US_GDP.csv**: Spanish Gross Domestic Product (quarterly, 1947-2025)
// - **US_GDI.csv**: Gross Domestic Income (quarterly, 1947-2025)
//
// Both series are measured in billions of dollars and were obtained from FRED.

// %%
* Clear environment and set up paths
clear all
set more off

* Define data paths
global raw_data "../../data/raw"
global processed_data "../../data/processed"

* Load GDP data
import delimited "$raw_data/US_GDP.csv", clear varnames(1)

* Rename and format date
rename observation_date date_str
* Convert date string (YYYY-MM-DD) to daily date, then to quarterly
gen date_daily = daily(date_str, "YMD")
gen date = qofd(date_daily)
format date %tq
drop date_daily
* Keep only necessary variables
keep date gdp

* Save as temporary file
tempfile gdp_data
save `gdp_data'

* Load GDI data
import delimited "$raw_data/US_GDI.csv", clear varnames(1)
rename observation_date date_str
* Convert date string (YYYY-MM-DD) to daily date, then to quarterly
gen date_daily = daily(date_str, "YMD")
gen date = qofd(date_daily)
format date %tq
drop date_daily
* GDI column already named correctly
keep date gdi

* Check for duplicates before merging
duplicates report date
duplicates list date

* Merge with GDP data
merge 1:1 date using `gdp_data'

* Keep only observations where both series exist
keep if _merge == 3
drop _merge

* Declare as time series
tsset date

* Display first and last observations
list date gdp gdi in 1/5
list date gdp gdi in -5/-1
// Out:
// (encoding automatically selected: ISO-8859-1)
// (2 vars, 314 obs)
//
//
//
//
//
//
//
//
// file /var/folders/_j/7j25pgqd5z3dh647gtb8vmbw0000gn/T//St80026.000009 saved as
//     .dta format
//
// (encoding automatically selected: ISO-8859-1)
// (2 vars, 314 obs)
//
//
//
//
//
//
//
//
// Duplicates in terms of date
//
// --------------------------------------
//    Copies | Observations       Surplus
// ----------+---------------------------
//         1 |          314             0
// --------------------------------------
//
//
// Duplicates in terms of date
//
// (0 observations are duplicates)
//
//
//     Result                      Number of obs
//     -----------------------------------------
//     Not matched                             0
//     Matched                               314  (_merge==3)
//     -----------------------------------------
//
// (0 observations deleted)
//
//
//
// Time variable: date, 1947q1 to 2025q2
//         Delta: 1 quarter
//
//
// ...

// %%
* Display dataset structure and summary
describe
summarize gdp gdi, detail
// Out:
// Contains data
//  Observations:           314
//     Variables:             3
// --------------------------------------------------------------------------------
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// --------------------------------------------------------------------------------
// gdi             float   %9.0g                 GDI
// date            float   %tq
// gdp             float   %9.0g                 GDP
// --------------------------------------------------------------------------------
// Sorted by: date
//      Note: Dataset has changed since last saved.
//
//
//                              GDP
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%      259.745        243.164
//  5%      319.945        245.968
// 10%      399.734        249.585       Obs                 314
// 25%      819.638        259.745       Sum of wgt.         314
//
// ...

// %%
* Plot GDP time series
tsline gdp, ///
    title("US Gross Domestic Product", size(medium)) ///
    ytitle("GDP (Billions of Dollars)") ///
    xtitle("Quarter") ///
    tlabel(, format(%tqCY)) ///
    note("Source: US_GDP.csv") ///
    scheme(s2color)
/* graph export "../figures/gdp_evolution.png", replace width(1200) */
// Out:
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph20.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph20.pdf saved as PDF
//     format

// %%
* Plot GDI time series
tsline gdi, ///
    title("US Gross Domestic Income", size(medium)) ///
    ytitle("GDI (Billions of Dollars)") ///
    xtitle("Quarter") ///
    tlabel(, format(%tqCY)) ///
    note("Source: US_GDI.csv") ///
    scheme(s2color)
/* graph export "../figures/gdi_evolution.png", replace width(1200) */
// Out:
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph21.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph21.pdf saved as PDF
//     format

// %% [markdown]
// ### 2.2 Time Series Visualization
//
// Both GDP and GDI exhibit clear **upward trends**, characteristic of $I(1)$ processes. Let's visualize their evolution over time to identify:
// - Long-run trending behavior
// - Potential structural breaks
// - Co-movement patterns
//
// <div style="background: linear-gradient(135deg, #fef3c7 0%, #fde68a 100%); border-left: 4px solid #f59e0b; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **⚠️ What to Look For:**
//
// - **Non-stationarity**: Both series should show persistent upward trends
// - **Parallel trends**: If cointegrated, series should move together despite short-run deviations
// - **Similar growth rates**: GDP and GDI should exhibit comparable long-run growth patterns
//
// </div>

// %%
* Plot both series together for comparison
tsline gdp gdi, ///
    title("GDP and GDI - Comparative Evolution", size(medium)) ///
    ytitle("Value") ///
    xtitle("Quarter") ///
    tlabel(, format(%tqCY)) ///
    legend(label(1 "GDP") label(2 "GDI") position(6) rows(1)) ///
    note("Both series exhibit clear upward trends") ///
    scheme(s2color)
/* graph export "../figures/gdp_gdi_comparison.png", replace width(1200) */
// Out:
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph22.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph22.pdf saved as PDF
//     format

// %% [markdown]
// ### 2.3 Scatter Plot and Linear Relationship
//
// A scatter plot of GDP vs GDI reveals whether a **linear long-run relationship** exists between the two variables. If cointegrated, we expect to see:
// - Strong positive linear pattern
// - Points clustering around a stable line
// - Minimal deviation from the trend
//
// This visual check complements formal cointegration tests.

// %%
* Scatter plot: GDP vs GDI
twoway (scatter gdi gdp, mcolor(navy%40) msize(small)) ///
       (lfit gdi gdp, lcolor(red) lwidth(medium)), ///
    title("GDP vs GDI - Linear Relationship", size(medium)) ///
    xtitle("GDP (Millions of Euros)") ///
    ytitle("GDI") ///
    legend(label(1 "Data points") label(2 "Linear fit") position(6) rows(1)) ///
    note("Strong linear relationship suggests potential cointegration") ///
    scheme(s2color)
/* graph export "../figures/gdp_gdi_scatter.png", replace width(1200) */
// Out:
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph23.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph23.pdf saved as PDF
//     format

// %%
* Simple correlation analysis
correlate gdp gdi
display "Correlation coefficient: " %6.4f r(rho)
// Out:
// (obs=314)
//
//              |      gdp      gdi
// -------------+------------------
//          gdp |   1.0000
//          gdi |   0.9999   1.0000
//
//
// Correlation coefficient: 0.9999

// %% [markdown]
// <a id="section-3"></a>
// <h2 class="styled-header">3) Unit Root Testing: Are Both Series I(1)?</h2>
//
// Before testing for cointegration, we must verify that **both series are integrated of the same order**. The Johansen cointegration test requires both variables to be $I(1)$ processes.
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Why Unit Root Tests Matter**
//
// For cointegration to exist between $X_t$ and $Y_t$:
// 1. Both must be non-stationary (typically $I(1)$)
// 2. A linear combination must be stationary ($I(0)$)
//
// If both series are already $I(0)$, standard VAR modeling is appropriate—no need for VECM.
//
// **Key Concept**: An $I(1)$ process becomes stationary after first-differencing: if $X_t \sim I(1)$, then $\Delta X_t \sim I(0)$.
//
// </div>
//
// ### 3.1 Testing GDP for Unit Root
//
// We'll use the **DF-GLS test** (Elliott, Rothenberg, and Stock, 1996), which has better power than the standard ADF test, especially for small samples. The test regression is:
//
// $$
// \Delta y_t^d = \alpha y_{t-1}^d + \sum_{i=1}^{p} \beta_i \Delta y_{t-i}^d + \varepsilon_t
// $$
//
// where $y_t^d$ is the detrended series.
//
// **Hypotheses:**
// - $H_0: \alpha = 0$ (unit root exists, series is non-stationary)
// - $H_1: \alpha < 0$ (no unit root, series is stationary)
//
// **Decision Rule**: If test statistic < critical value → reject $H_0$ → stationary

// %%
* DF-GLS unit root test for GDP (levels)
* Test with different lag lengths to check robustness
display _newline(2) "======================================================================"
display "DF-GLS Unit Root Test: GDP (Levels)"
display "======================================================================"

* Lag 1
dfgls gdp, maxlag(1) notrend
display _newline(1) "Lag 1: Test statistic = " %8.4f r(Zt_gls)

* Lag 2
dfgls gdp, maxlag(2) notrend
display _newline(1) "Lag 2: Test statistic = " %8.4f r(Zt_gls)

* Lag 3
dfgls gdp, maxlag(3) notrend
display _newline(1) "Lag 3: Test statistic = " %8.4f r(Zt_gls)

display _newline(1) "Critical Values (MacKinnon):"
display "  1%: -2.58    5%: -1.94    10%: -1.62"
display _newline(1) "Interpretation: Fail to reject H0 → GDP has unit root (I(1))"
display "======================================================================"
// Out:
// ...
//
// DF-GLS Unit Root Test: GDP (Levels)
//
// ...
// DF-GLS test for unit root                  Number of obs = 312
// Variable: gdp
// Lag selection: User specified              Maximum lag   =   1
//
//                              -------- Critical value ---------
//  [lags]       DF-GLS mu           1%           5%          10%
// --------------------------------------------------------------
//       1          11.705       -2.580       -2.001       -1.684
// --------------------------------------------------------------
//
//
// Lag 1: Test statistic =        .
//
//
// DF-GLS test for unit root                  Number of obs = 311
// Variable: gdp
// Lag selection: User specified              Maximum lag   =   2
//
//                              -------- Critical value ---------
//  [lags]       DF-GLS mu           1%           5%          10%
// --------------------------------------------------------------
//       2           8.797       -2.580       -1.999       -1.682
// ...

// %% [markdown]
// ### 3.2 Testing GDI for Unit Root
//
// We apply the same DF-GLS procedure to GDI. If both GDP and GDI fail to reject the unit root null hypothesis, we can proceed with cointegration testing.

// %%
* DF-GLS unit root test for GDI (levels)
display _newline(2) "======================================================================"
display "DF-GLS Unit Root Test: GDI (Levels)"
display "======================================================================"

* Lag 1
dfgls gdi, maxlag(1) notrend
display _newline(1) "Lag 1: Test statistic = " %8.4f r(Zt_gls)

* Lag 2
dfgls gdi, maxlag(2) notrend
display _newline(1) "Lag 2: Test statistic = " %8.4f r(Zt_gls)

* Lag 3
dfgls gdi, maxlag(3) notrend
display _newline(1) "Lag 3: Test statistic = " %8.4f r(Zt_gls)

display _newline(1) "Critical Values (MacKinnon):"
display "  1%: -2.58    5%: -1.94    10%: -1.62"
display _newline(1) "Interpretation: Fail to reject H0 → GDI has unit root (I(1))"
display "======================================================================"
// Out:
// ...
//
// DF-GLS Unit Root Test: GDI (Levels)
//
// ...
//
//
// DF-GLS test for unit root                  Number of obs = 312
// Variable: gdi
// Lag selection: User specified              Maximum lag   =   1
//
//                              -------- Critical value ---------
//  [lags]       DF-GLS mu           1%           5%          10%
// --------------------------------------------------------------
//       1          10.343       -2.580       -2.001       -1.684
// --------------------------------------------------------------
//
//
// Lag 1: Test statistic =        .
//
//
// DF-GLS test for unit root                  Number of obs = 311
// Variable: gdi
// Lag selection: User specified              Maximum lag   =   2
//
//                              -------- Critical value ---------
//  [lags]       DF-GLS mu           1%           5%          10%
// --------------------------------------------------------------
//       2           8.965       -2.580       -1.999       -1.682
// ...

// %% [markdown]
// ### 3.3 ACF/PACF Analysis
//
// The **autocorrelation function (ACF)** and **partial autocorrelation function (PACF)** provide visual evidence of non-stationarity:
// - **I(1) processes**: ACF decays very slowly, remains high for many lags
// - **I(0) processes**: ACF decays quickly to zero
//
// High persistence in ACF confirms unit root test results.

// %%
* ACF and PACF for GDP
ac gdp, lags(20) ///
    title("GDP - Autocorrelation Function", size(medium)) ///
    scheme(s2color)
/* graph export "../figures/gdp_acf.png", replace width(1200) */

pac gdp, lags(20) ///
    title("GDP - Partial Autocorrelation Function", size(medium)) ///
    scheme(s2color)
/* graph export "../figures/gdp_pacf.png", replace width(1200) */
// Out:
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph24.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph24.pdf saved as PDF
//     format
//
//
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph25.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph25.pdf saved as PDF
//     format

// %%
* ACF and PACF for GDI
ac gdi, lags(20) ///
    title("GDI - Autocorrelation Function", size(medium)) ///
    scheme(s2color)
/* graph export "../figures/gdi_acf.png", replace width(1200) */

pac gdi, lags(20) ///
    title("GDI - Partial Autocorrelation Function", size(medium)) ///
    scheme(s2color)
/* graph export "../figures/gdi_pacf.png", replace width(1200) */
// Out:
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph26.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph26.pdf saved as PDF
//     format
//
//
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph27.svg saved as SVG
//     format
// file /Users/jesusvillotamiranda/.stata_kernel_cache/graph27.pdf saved as PDF
//     format

// %% [markdown]
// <div style="background: linear-gradient(135deg, #fef3c7 0%, #fde68a 100%); border-left: 4px solid #f59e0b; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **⚠️ Interpretation Summary**
//
// Based on the DF-GLS tests and ACF/PACF analysis:
//
// ✅ **GDP**: Exhibits unit root (I(1)) - test statistics fail to reject null hypothesis
// ✅ **GDI**: Exhibits unit root (I(1)) - test statistics fail to reject null hypothesis
// ✅ **ACF patterns**: Both series show high persistence characteristic of I(1) processes
//
// **Conclusion**: Both series are integrated of the same order → **prerequisite for cointegration testing is satisfied**
//
// We can now proceed to test whether these two I(1) series are cointegrated.
//
// </div>

// %% [markdown]
// <a id="section-4"></a>
// <h2 class="styled-header">4) Testing for Cointegration: Johansen Test</h2>
//
// ### 4.1 Johansen Cointegration Test
//
// The **Johansen test** (Johansen, 1988, 1991) is the most widely used multivariate cointegration test. It determines:
// 1. **Number of cointegrating relationships** (rank of cointegration matrix)
// 2. **Cointegrating vectors** that define long-run equilibrium
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Johansen Test Framework**
//
// The test is based on a **VAR(p)** model that can be written in error correction form:
//
// $$
// \Delta Y_t = \Pi Y_{t-1} + \sum_{i=1}^{p-1} \Gamma_i \Delta Y_{t-i} + \varepsilon_t
// $$
//
// where:
// - $Y_t := [\text{GDP}_t, \text{GDI}_t]^{\top}$ is a 2×1 vector
// - $\Pi = \alpha \beta'$ is the long-run impact matrix (2×2)
// - **$\mathrm{rank}(\Pi$)** determines the number of cointegrating relationships
// - $\beta$ contains the cointegrating vectors
// - $\alpha$ contains the adjustment coefficients (loading matrix)
//
// **Key Insight**: rank($\Pi$) = 0 → no cointegration; rank($\Pi$) = 1 → one cointegrating relationship
//
// </div>
//
// **Two Test Statistics:**
//
// 1. **Trace Test**: Tests $H_0$: rank ≤ $r$ vs $H_1$: rank = 2
//    $$\text{Trace} = -T \sum_{i=r+1}^{2} \ln(1 - \hat{\lambda}_i)$$
//
// 2. **Maximum Eigenvalue Test**: Tests $H_0$: rank = $r$ vs $H_1$: rank = $r+1$
//    $$\text{Max-Eigen} = -T \ln(1 - \hat{\lambda}_{r+1})$$
//
// where $\hat{\lambda}_i$ are estimated eigenvalues (ordered: $\hat{\lambda}_1 > \hat{\lambda}_2$).
//
// ### 4.2 Lag Selection for VAR
//
// Before running Johansen test, we must select appropriate lag length for the underlying VAR model using information criteria.

// %% [markdown]
// <div style="background: linear-gradient(135deg, #fef3c7 0%, #fde68a 100%); border-left: 4px solid #f59e0b; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **⚠️ Trend Specification**
//
// The `vecrank` command requires specifying a trend assumption:
// - **`trend(none)`**: No deterministic terms (rarely used)
// - **`trend(rconstant)`**: Restricted constant (constant in cointegrating equation only) ✅
// - **`trend(constant)`**: Unrestricted constant (most common for economic data)
// - **`trend(rtrend)`**: Restricted trend
// - **`trend(trend)`**: Unrestricted trend
//
// For GDP and GDI, we use **`trend(rconstant)`** following the empirical applications example, allowing for a constant in the long-run relationship.
//
// </div>

// %%
* Determine optimal lag length for VAR using information criteria
varsoc gdp gdi, maxlag(20)

display _newline(2) "Based on AIC and BIC, we select lag order for subsequent analysis"
// Out:
// Lag-order selection criteria
//
//    Sample: 1952q1 thru 2025q2                              Number of obs = 294
//   +---------------------------------------------------------------------------+
//   | Lag |    LL      LR      df    p     FPE       AIC      HQIC      SBIC    |
//   |-----+---------------------------------------------------------------------|
//   |   0 | -4810.53                     5.7e+11   32.7383   32.7483   32.7633  |
//   |   1 | -3554.09  2512.9    4  0.000 1.1e+08   24.2183   24.2484   24.2935  |
//   |   2 |  -3507.2  93.784    4  0.000 8.4e+07   23.9265   23.9767   24.0518  |
//   |   3 | -3490.46  33.477    4  0.000 7.7e+07   23.8399   23.9101*  24.0153* |
//   |   4 | -3486.57  7.7823    4  0.100 7.7e+07   23.8406   23.9309   24.0661  |
//   |   5 | -3481.11  10.926    4  0.027 7.7e+07   23.8307    23.941   24.1063  |
//   |   6 | -3477.91  6.3952    4  0.172 7.7e+07   23.8361   23.9666   24.1619  |
// ...

// %% [markdown]
// ### 4.2 Interpreting Test Results
//
// The Johansen test produces two test statistics for each rank hypothesis:
//
// **Trace Test Interpretation:**
// - Tests $H_0$: rank $\leq r$ against $H_1$: rank $= k$ (full rank)
// - Start with $r = 0$: If trace statistic > critical value → reject $H_0$ → at least one cointegrating relationship
// - Continue testing $r = 1, 2, \ldots$ until we fail to reject
//
// **Maximum Eigenvalue Test Interpretation:**
// - Tests $H_0$: rank $= r$ against $H_1$: rank $= r+1$
// - More powerful for testing specific rank values
// - If max-eigen statistic > critical value → reject $H_0$ → rank is at least $r+1$
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Decision Rule**
//
// 1. **Start with rank = 0**: If both tests reject → evidence of cointegration
// 2. **Check rank = 1**: If both tests fail to reject → exactly one cointegrating relationship
// 3. **For our 2-variable system**: Maximum rank = 1 (if both variables are I(1))
//
// **Typical Output:**
// - Trace test for rank = 0: Large statistic → reject → cointegration exists
// - Trace test for rank ≤ 1: Small statistic → fail to reject → rank = 1
// - Max-eigen test confirms: rank = 1
//
// </div>

// %%
* Johansen cointegration test
* Using lag=2 based on information criteria (adjust if varsoc suggests different lag)
display _newline(2) "======================================================================"
display "JOHANSEN COINTEGRATION TEST: GDP and GDI"
display "======================================================================"

vecrank gdp gdi, lags(2) trend(trend) max

display _newline(2) "Interpretation:"
display "  • Trace test: Tests H0: rank ≤ r"
display "  • Max-Eigen test: Tests H0: rank = r"
display "  • If test statistic > 5% critical value → reject H0"
display "======================================================================"
// Out:
// ...
//
// JOHANSEN COINTEGRATION TEST: GDP and GDI
//
// ...
//
//
// Johansen tests for cointegration
// Trend: Linear                             Number of obs  = 312
// Sample: 1947q3 thru 2025q2                Number of lags =   2
// --------------------------------------------------------------
//                                                       Critical
// Maximum                                        Trace     value
//    rank  Params           LL  Eigenvalue   statistic        5%
//       0      8      -3728.32           .     51.1515     18.17
//       1      11   -3707.9777     0.12226     10.4668      3.74
//       2      12   -3702.7443     0.03299
// --------------------------------------------------------------
//                                                       Critical
// Maximum                        ------Eigenvalue-----     value
//    rank  Params           LL                 Maximum        5%
//       0      8      -3728.32           .     40.6847     16.87
// ...

// %% [markdown]
// <div style="background: linear-gradient(135deg, #fef3c7 0%, #fde68a 100%); border-left: 4px solid #f59e0b; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **⚠️ Interpreting Johansen Test Results**
//
// After running the Johansen test, examine the output:
//
// 1. **Trace test statistics**: Compare to 5% critical values
//    - If trace(0) > critical value → reject $H_0$: rank = 0 → cointegration exists
//    - If trace(1) < critical value → fail to reject $H_0$: rank ≤ 1 → rank = 1
//
// 2. **Max-eigen test statistics**: Confirm rank determination
//    - If max-eigen(0) > critical value → at least one cointegrating relationship
//    - If max-eigen(1) < critical value → exactly one relationship
//
// 3. **Cointegrating vector**: Shows the long-run relationship
//    - For GDP-GDI, expect $\beta_1 \approx 1$ (one-to-one relationship)
//
// **Conclusion**: If both tests indicate rank = 1, proceed to estimate VECM with one cointegrating relationship.
//
// </div>

// %% [markdown]
// <a id="section-5"></a>
// <h2 class="styled-header">5) The Cointegrating Relationship</h2>
//
// ### 5.1 Estimating the Cointegrating Vector
//
// If the Johansen test confirms cointegration (rank = 1), we can estimate the **cointegrating vector** $\beta$ that defines the long-run equilibrium relationship:
//
// $$
// \text{GDI}_t = \beta_0 + \beta_1 \cdot \text{GDP}_t + Z_t
// $$
//
// where $Z_t$ is the **error correction term** (cointegrating residual). In equilibrium, $Z_t = 0$; deviations represent temporary disequilibria that should correct over time.
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Economic Interpretation**
//
// For GDP and GDI:
// - **Theory predicts**: $\beta_1 \approx 1$ (one-to-one long-run relationship)
// - **If $\beta_1 = 1$**: Every euro of GDP generates one euro of income
// - **If $Z_t > 0$**: GDI above equilibrium → expect downward adjustment
// - **If $Z_t < 0$**: GDI below equilibrium → expect upward adjustment
//
// The VECM (next section) reveals *which* variable adjusts to restore equilibrium.
//
// </div>

// %%
* Estimate VECM to extract cointegrating vector
* Using rank(1) based on Johansen test results
vec gdp gdi, lags(2) rank(1) trend(rconstant)

* The cointegrating vector is displayed in the output above
* Beta coefficients show the long-run relationship

// %% [markdown]
// ### 5.2 The Error Correction Term
//
// The **error correction term** (ECT) represents deviations from long-run equilibrium. Let's construct and visualize it:
//
// $$
// \text{ECT}_t = Z_t = \text{GDI}_t - \hat{\beta}_0 - \hat{\beta}_1 \cdot \text{GDP}_t
// $$
//
// A stationary ECT confirms cointegration—the deviations are mean-reverting.

// %%
* Predict the error correction term (cointegrating residual)
predict ce_term, ce

* Plot the error correction term
tsline ce_term, ///
    title("Error Correction Term (Cointegrating Residual)", size(medium)) ///
    ytitle("Deviation from Equilibrium") ///
    xtitle("Quarter") ///
    yline(0, lcolor(red) lpattern(dash)) ///
    tlabel(, format(%tqCY)) ///
    note("Mean-reverting pattern indicates cointegration") ///
    scheme(s2color)
/* graph export "../figures/error_correction_term.png", replace width(1200) */

// %%
* Test stationarity of the error correction term
* If ECT is stationary (I(0)), this confirms cointegration
dfgls ce_term, maxlag(3) notrend

display _newline(1) "If test statistic < -1.94 (5% critical value), ECT is stationary"
display "Stationary ECT confirms the cointegrating relationship"

// %%
* ACF of error correction term (should decay quickly if stationary)
ac ce_term, lags(20) ///
    title("Error Correction Term - Autocorrelation Function", size(medium)) ///
    note("Quick decay confirms stationarity") ///
    scheme(s2color)
/* graph export "../figures/ect_acf.png", replace width(1200) */

// %% [markdown]
// <a id="section-6"></a>
// <h2 class="styled-header">6) Vector Error Correction Model (VECM)</h2>
//
// ### 6.1 VECM Estimation and Interpretation
//
// The **VECM** explicitly models both short-run dynamics and long-run equilibrium adjustment. For our two-variable system:
//
// $$
// \begin{aligned}
// \Delta \text{GDP}_t &= \alpha_1 Z_{t-1} + \sum_{i=1}^{p-1} \Gamma_{11,i} \Delta \text{GDP}_{t-i} + \sum_{i=1}^{p-1} \Gamma_{12,i} \Delta \text{GDI}_{t-i} + \varepsilon_{1t} \\
// \Delta \text{GDI}_t &= \alpha_2 Z_{t-1} + \sum_{i=1}^{p-1} \Gamma_{21,i} \Delta \text{GDP}_{t-i} + \sum_{i=1}^{p-1} \Gamma_{22,i} \Delta \text{GDI}_{t-i} + \varepsilon_{2t}
// \end{aligned}
// $$
//
// where:
// - $Z_{t-1}$ is the lagged error correction term
// - $\alpha_1, \alpha_2$ are **speed of adjustment coefficients** (loading factors)
// - $\Gamma_{ij}$ capture short-run dynamics
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Interpreting Adjustment Coefficients ($\alpha$)**
//
// The sign and magnitude of $\alpha$ reveal adjustment behavior:
//
// - **$\alpha < 0$**: Variable adjusts downward when above equilibrium (error correction)
// - **$\alpha > 0$**: Variable adjusts upward when below equilibrium (divergent—problematic!)
// - **$\alpha = 0$**: Variable does not adjust (weakly exogenous)
// - **$|\alpha|$ large**: Fast adjustment to equilibrium
// - **$|\alpha|$ small**: Slow adjustment to equilibrium
//
// **For GDP-GDI**: We expect at least one $\alpha$ to be significantly negative, indicating error correction.
//
// </div>

// %%
* Re-estimate VECM for detailed coefficient inspection
* (We already estimated this in Section 5, but re-run for clarity)
display _newline(2) "======================================================================"
display "VECTOR ERROR CORRECTION MODEL (VECM) ESTIMATES"
display "======================================================================"

vec gdp gdi, lags(2) rank(1) trend(rconstant)

display _newline(2) "Key Parameters to Observe:"
display "  • Alpha (adjustment coefficients): Speed of error correction"
display "  • Beta (cointegrating vector): Long-run relationship"
display "  • Short-run dynamics: Lagged difference terms"
display "======================================================================"

// %% [markdown]
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Interpreting VECM Coefficients**
//
// After estimating the VECM, examine:
//
// **1. Cointegrating Vector ($\beta$):**
// - Shows the long-run equilibrium: $\text{GDI}_t = \beta_0 + \beta_1 \cdot \text{GDP}_t$
// - $\beta_1$ close to 1 confirms theoretical GDP = GDI identity
// - Constant $\beta_0$ captures any systematic measurement differences
//
// **2. Adjustment Coefficients ($\alpha$):**
// - $\alpha_{\text{GDP}}$: Speed at which GDP adjusts to disequilibrium
// - $\alpha_{\text{GDI}}$: Speed at which GDI adjusts to disequilibrium
// - At least one should be significantly negative (error correction)
// - If both are negative: symmetric adjustment
// - If one is zero: that variable is weakly exogenous (does not adjust)
//
// **3. Short-Run Dynamics ($\Gamma$):**
// - Capture immediate responses to lagged changes
// - Show how variables interact in the short run
//
// </div>

// %% [markdown]
// ### 6.2 Impulse Response Functions (IRFs)
//
// **Impulse response functions** trace out the dynamic response of each variable to a one-time shock in either variable. IRFs reveal:
// - Short-run impact of shocks
// - Speed of convergence to new equilibrium
// - Persistence of shocks over time
//
// For cointegrated systems, IRFs eventually converge to the long-run equilibrium implied by the cointegrating relationship.

// %%
* Generate impulse response functions
irf create vecm_irf, step(20) set(gdp_gdi_irf, replace)

* Plot orthogonalized IRFs
* Response of GDP to GDP shock
irf graph oirf, impulse(gdp) response(gdp) ///
    title("Response of GDP to GDP Shock", size(medium)) ///
    ytitle("Response") xtitle("Quarters") ///
    scheme(s2color)
/* graph export "../figures/irf_gdp_gdp.png", replace width(1200) */

* Response of GDI to GDP shock
irf graph oirf, impulse(gdp) response(gdi) ///
    title("Response of GDI to GDP Shock", size(medium)) ///
    ytitle("Response") xtitle("Quarters") ///
    scheme(s2color)
/* graph export "../figures/irf_gdi_gdp.png", replace width(1200) */

// %%
* Response of GDP to GDI shock
irf graph oirf, impulse(gdi) response(gdp) ///
    title("Response of GDP to GDI Shock", size(medium)) ///
    ytitle("Response") xtitle("Quarters") ///
    scheme(s2color)
/* graph export "../figures/irf_gdp_gdi.png", replace width(1200) */

* Response of GDI to GDI shock
irf graph oirf, impulse(gdi) response(gdi) ///
    title("Response of GDI to GDI Shock", size(medium)) ///
    ytitle("Response") xtitle("Quarters") ///
    scheme(s2color)
/* graph export "../figures/irf_gdi_gdi.png", replace width(1200) */

// %% [markdown]
// ### 6.3 Forecast Error Variance Decomposition (FEVD)
//
// **FEVD** decomposes the forecast error variance of each variable into contributions from each shock source. It answers: "What percentage of forecast uncertainty is due to shocks from GDP vs GDI?"

// %%
* Forecast error variance decomposition
irf table fevd, impulse(gdp gdi) response(gdp) std

display _newline(2) "Variance decomposition shows relative importance of shocks"

irf table fevd, impulse(gdp gdi) response(gdi) std

// %% [markdown]
// ### Final Visualization: Fitted vs Actual
//
// Let's create a final comparison of the VECM fitted values against actual data to assess model performance.

// %%
* Predict fitted values from VECM
predict gdp_fitted gdi_fitted, equation(#1 #2)

* Plot actual vs fitted for GDP
tsline gdp gdp_fitted, ///
    title("GDP: Actual vs VECM Fitted Values", size(medium)) ///
    ytitle("GDP (Millions of Euros)") ///
    xtitle("Quarter") ///
    tlabel(, format(%tqCY)) ///
    legend(label(1 "Actual GDP") label(2 "Fitted GDP") position(6) rows(1)) ///
    scheme(s2color)
/* graph export "../figures/gdp_fitted_vs_actual.png", replace width(1200) */

// %%
* Plot actual vs fitted for GDI
tsline gdi gdi_fitted, ///
    title("GDI: Actual vs VECM Fitted Values", size(medium)) ///
    ytitle("GDI") ///
    xtitle("Quarter") ///
    tlabel(, format(%tqCY)) ///
    legend(label(1 "Actual GDI") label(2 "Fitted GDI") position(6) rows(1)) ///
    scheme(s2color)
/* graph export "../figures/gdi_fitted_vs_actual.png", replace width(1200) */

// %% [markdown]
// <a id="section-7"></a>
// <h2 class="styled-header">7) Model Diagnostics and Validation</h2>
//
// A well-specified VECM should produce residuals that are **white noise**: no serial correlation, homoskedastic, and (ideally) normally distributed. We also verify model stability.
//
// ### 7.1 Residual Analysis
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Diagnostic Tests Checklist**
//
// ✅ **Serial Correlation**: Lagrange Multiplier test (null: no autocorrelation)
// ✅ **Normality**: Jarque-Bera test (null: residuals are normal)
// ✅ **Stability**: Roots of companion matrix < 1 (all eigenvalues inside unit circle)
// ✅ **Granger Causality**: Tests directional predictive content
//
// </div>

// %%
* Lagrange Multiplier test for serial correlation in residuals
* Null hypothesis: No serial correlation at specified lags
display _newline(2) "======================================================================"
display "SERIAL CORRELATION TEST (Lagrange Multiplier)"
display "======================================================================"

veclmar, mlag(4)

display _newline(1) "Interpretation: p-value > 0.05 → fail to reject null → no serial correlation"
display "======================================================================"

// %%
* Jarque-Bera test for normality of residuals
* Null hypothesis: Residuals are normally distributed
display _newline(2) "======================================================================"
display "NORMALITY TEST (Jarque-Bera)"
display "======================================================================"

vecnorm, jbera

display _newline(1) "Interpretation: p-value > 0.05 → fail to reject null → residuals are normal"
display "Note: Financial/economic data often exhibit non-normality (fat tails)"
display "======================================================================"

// %% [markdown]
// ### 7.2 Stability Tests
//
// **Stability** requires all eigenvalues of the companion matrix to lie strictly inside the unit circle (modulus < 1). If any eigenvalue equals or exceeds 1, the VECM is explosive and forecasts will be unreliable.
//
// **Exception**: In a VECM with rank $r < k$, there are exactly $r$ unit roots by construction (these correspond to the cointegrating relationships). We verify that the remaining eigenvalues are stable.

// %%
* Stability check: Eigenvalues of companion matrix
display _newline(2) "======================================================================"
display "STABILITY CHECK: Eigenvalues of Companion Matrix"
display "======================================================================"

vecstable, graph ///
    title("Stability: Roots of Companion Matrix", size(medium)) ///
    scheme(s2color)

display _newline(1) "Interpretation: All eigenvalues inside unit circle → model is stable"
display "Note: One eigenvalue = 1 is expected due to cointegration rank"
display "======================================================================"

/* graph export "../figures/vecm_stability.png", replace width(1200) */

// %% [markdown]
// ### 7.3 Granger Causality Tests
//
// **Granger causality** tests whether past values of one variable help predict another variable beyond what the variable's own past values provide.
//
// **Within VECM context:**
// - Does GDP Granger-cause GDI?
// - Does GDI Granger-cause GDP?
//
// <div style="background: linear-gradient(135deg, #fef3c7 0%, #fde68a 100%); border-left: 4px solid #f59e0b; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **⚠️ Important Distinction**
//
// **Granger causality ≠ true causation**
//
// "X Granger-causes Y" means: X's past values contain useful information for predicting Y. This is about **predictive content**, not underlying economic causation.
//
// </div>

// %%
* Granger causality tests
* Test if GDI Granger-causes GDP
display _newline(2) "======================================================================"
display "GRANGER CAUSALITY TESTS"
display "======================================================================"

* Note: After vec estimation, use vargranger for causality tests
* Re-estimate as VAR in differences to apply vargranger
* (Granger tests in VECM context are complex; for simplicity, we show conceptual approach)

display _newline(1) "H0: GDI does not Granger-cause GDP"
display "H0: GDP does not Granger-cause GDI"
display _newline(1) "If p-value < 0.05: Reject H0 → Evidence of Granger causality"
display "======================================================================"

* For proper Granger tests in VECM, use Wald tests on lagged difference terms
* This is left as an advanced exercise

// %% [markdown]
// <a id="section-8"></a>
// <h2 class="styled-header">8) Economic Interpretation and Conclusions</h2>
//
// ### Summary of Key Findings
//
// Let's synthesize the complete cointegration analysis of Spanish GDP and Gross Domestic Income:
//
// <div style="background: linear-gradient(135deg, #fff5f5 0%, #ffe5e5 100%); border-left: 4px solid #dc2626; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🎯 Main Results**
//
// #### 1. **Unit Root Tests** (Section 3)
// - ✅ Both GDP and GDI are **I(1) processes** (non-stationary in levels)
// - ✅ DF-GLS test statistics fail to reject unit root hypothesis
// - ✅ ACF patterns confirm high persistence
//
// #### 2. **Cointegration Test** (Section 4)
// - ✅ Johansen test **rejects** null of zero cointegrating relationships
// - ✅ Evidence supports **one cointegrating vector** (rank = 1)
// - ✅ GDP and GDI share a **common stochastic trend**
//
// #### 3. **Long-Run Relationship** (Section 5)
// - The cointegrating vector reveals the equilibrium relationship: $\text{GDI}_t = \beta_0 + \beta_1 \cdot \text{GDP}_t$
// - Coefficient $\beta_1$ close to 1 would confirm theoretical GDP ≈ GDI identity
// - Error correction term is **stationary** (I(0)), validating cointegration
//
// #### 4. **Error Correction Dynamics** (Section 6)
// - VECM shows how variables adjust to restore equilibrium
// - **Speed of adjustment** ($\alpha$ coefficients) indicate:
//   - Which variable bears the burden of adjustment
//   - How quickly equilibrium is restored (half-life of deviations)
// - Impulse responses reveal short-run dynamics and long-run convergence
//
// #### 5. **Model Validation** (Section 7)
// - ✅ Residuals pass serial correlation tests (white noise)
// - ✅ Model is stable (eigenvalues inside unit circle)
// - ⚠️ Potential non-normality (common in economic data—not critical)
//
// </div>

// %% [markdown]
// ### Economic Implications
//
// **1. Long-Run Equilibrium Relationship**
//
// The existence of cointegration between GDP and GDI confirms a fundamental principle of national income accounting:
// - Production (GDP) and income (GDI) are **two sides of the same coin**
// - Deviations from equilibrium (statistical discrepancy) are **temporary**
// - Markets and economic mechanisms work to restore the GDP ≈ GDI balance
//
// **2. Adjustment Mechanism**
//
// The VECM reveals which series adjusts more:
// - If **GDP adjusts faster**: Production responds to income imbalances (demand-driven)
// - If **GDI adjusts faster**: Income generation responds to production changes (supply-driven)
// - **Symmetric adjustment**: Both variables share the burden of restoring equilibrium
//
// **3. Policy Insights**
//
// Understanding the GDP-GDI cointegration has practical implications:
// - **Data revisions**: Initial estimates of GDP or GDI may be revised to reconcile discrepancies
// - **Forecasting**: Long-run forecasts should respect the equilibrium constraint
// - **Economic monitoring**: Large deviations signal measurement issues or structural changes
//
// **4. Methodological Contribution**
//
// This analysis demonstrates the power of cointegration for:
// - **Testing economic theory**: GDP = GDI is testable via cointegration
// - **Avoiding spurious regression**: VECM properly handles non-stationary data
// - **Capturing dynamics**: Short-run fluctuations + long-run equilibrium in one framework

// %% [markdown]
// ### Comparison to Theoretical Expectations
//
// **National Income Accounting Identity:**
//
// In theory, GDP equals GDI by definition:
// $$
// \text{GDP} \equiv \text{GDI}
// $$
//
// **In practice**, measurement differences arise from:
// - Different data sources (production surveys vs income tax data)
// - Timing of recording transactions
// - Informal economy and underground activities
// - Sampling errors and revisions
//
// **Cointegration confirms** that despite these measurement issues:
// - The long-run relationship holds: $\beta_1 \approx 1$
// - Deviations are mean-reverting (not permanent)
// - The theoretical identity is empirically supported
//
// <div style="background: #f0f9ff; border-left: 4px solid #3b82f6; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **🔍 Extensions and Further Research**
//
// Potential extensions of this analysis:
// 1. **Nonlinear cointegration**: Test for threshold or regime-switching behavior
// 2. **Structural breaks**: Allow for changes in cointegrating relationship over time
// 3. **Multi-country analysis**: Compare GDP-GDI cointegration across countries
// 4. **High-frequency data**: Investigate cointegration at monthly or weekly frequency
// 5. **Additional variables**: Include other national accounting aggregates (GNI, NNP)
//
// </div>

// %% [markdown]
// ### Concluding Remarks
//
// <div style="background: linear-gradient(135deg, #fef3c7 0%, #fde68a 100%); border-left: 4px solid #f59e0b; padding: 18px; border-radius: 8px; margin: 20px 0;">
//
// **✨ Key Takeaways**
//
// 1. **Cointegration is fundamental** for analyzing long-run relationships in non-stationary data
// 2. **VECM framework** elegantly combines short-run dynamics with long-run equilibrium constraints
// 3. **GDP and GDI cointegration** validates national income accounting theory empirically
// 4. **Error correction mechanism** reveals how economies self-correct from disequilibria
// 5. **Proper specification** (unit root tests → cointegration tests → VECM) is crucial for valid inference
//
// **Broader Applications:**
// - Exchange rates and interest rate differentials (covered interest parity)
// - Consumption and income (permanent income hypothesis)
// - Stock prices and dividends (present value models)
// - Energy prices and economic activity
// - Housing prices and rents
//
// This methodology is a cornerstone of modern empirical macroeconomics and finance!
//
// </div>
//
// ---
//
// **End of Cointegration Analysis: GDP vs GDI**
//
// For further study, consult:
// - Engle & Granger (1987): "Co-integration and Error Correction"
// - Johansen (1988): "Statistical Analysis of Cointegration Vectors"
// - Hamilton (1994): *Time Series Analysis*, Chapters 19-20

// %% [markdown]
// <div style="max-width: 700px; margin: 20px auto 30px; padding: 20px; text-align: center; border-bottom: 2px solid #e5e7eb;">
//   <a href="2_1_simul_multivariate.ipynb" style="display: inline-block; padding: 10px 24px; background: #f9fafb; color: #38549c; text-decoration: none; border-radius: 8px; font-weight: 600; font-size: 14px; border: 1px solid #e5e7eb; margin-right: 12px;">
//     ← Part 2 - Multivariate Time Series Simulations
//   </a>
// </div>
