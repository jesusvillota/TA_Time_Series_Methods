// %% [markdown]
// # Topic 3: State Space Models and Kalman Filter
//
// **CEMFI Advanced Training School - Methods for Time Series**
// **Practical Session 2**
//
// ## Learning Objectives
// 1. Understand state space representation
// 2. Implement Kalman filter
// 3. Estimate dynamic factor models
// 4. Model time-varying parameters

// %%
* Setup
clear all
set more off
cd "../../data/processed"

// %%
* State space: trend/cycle decomposition
* sspace (trend lngdp, state) (lngdp trend, noerror)
* predict trend, state equation(trend)

// %%
* Time-varying beta
* sspace (beta stock_return market_return, state)
* predict beta_t, state equation(beta)

// %%
* Dynamic factor model
* dfactor (stock1 stock2 stock3 = , noconstant), ar(1)
* predict factor, dynamic
